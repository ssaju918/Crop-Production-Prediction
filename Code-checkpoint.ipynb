# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder
from sklearn import utils
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
data= pd.read_csv("Potato.csv")

# %%
data
# Out:
#       Year    District  Rainfall   MaxT   MinT  Humidity  Potato Area  \
# 0   2015.0  Chuadanga       27.0  30.50  16.45      72.5       3832.0
# 1   2016.0  Chuadanga       61.0  31.60  18.25      73.5       3964.0
# 2   2017.0  Chuadanga        4.5  23.70  16.45      70.0       4606.0
# 3   2018.0  Chuadanga        2.0  31.75  17.05      70.0       4612.0
# 4   2019.0  Chuadanga       47.5  30.25  15.80      71.5       4712.0
# 5   2020.0  Chuadanga       21.5  30.22  15.70      72.5       4899.0
# 6   2015.0    Jessore       59.0  31.10  16.95      69.5       7822.0
# 7   2016.0    Jessore       40.5  32.40  19.30      71.0       7785.0
# 8   2017.0    Jessore       12.0  24.15  16.95      69.5       7762.0
# 9   2018.0    Jessore        7.0  32.40  17.95      69.5       8701.0
# 10  2019.0    Jessore       87.5  30.55  16.50      71.0       6931.0
# 11  2020.0    Jessore       16.0  30.50  16.44      70.0       5933.0
# ...

# %%
model = data

# %%
model.groupby("Year").sum()['AR'].plot(figsize=(12,8));
model.groupby("Year").sum()['AH'].plot(figsize=(12,8));
model.groupby("Year").sum()['AMT'].plot(figsize=(12,8));
model.groupby("Year").sum()['AMiT'].plot(figsize=(12,8));
model.groupby("Year").sum()['AWS'].plot(figsize=(12,8));
model.groupby("Year").sum()['ACC'].plot(figsize=(12,8));
model.groupby("Year").sum()['ABS'].plot(figsize=(12,8));

plt.legend()

# %% [markdown]
# model.groupby("YEAR").sum()['R Pro'].plot(figsize=(12,8));
# model.groupby("YEAR").sum()['W Pro'].plot(figsize=(12,8));
# model.groupby("YEAR").sum()['GN Pro'].plot(figsize=(12,8));
# model.groupby("YEAR").sum()['Tob Pro'].plot(figsize=(12,8));
# model.groupby("YEAR").sum()['Ba Pro'].plot(figsize=(12,8));
# #model.groupby("YEAR").sum()['ACC'].plot(figsize=(12,8));
# #model.groupby("YEAR").sum()['ABS'].plot(figsize=(12,8));
#
# plt.legend()

# %%
model.groupby("Year").sum()['Aman Area'].plot(figsize=(12,6));
model.groupby("Year").sum()['Aman Production'].plot(figsize=(12,6));
#model.groupby("Year").sum()['Aus Area'].plot(figsize=(12,6));
#model.groupby("Year").sum()['Aus Production'].plot(figsize=(12,6));

plt.legend()
plt.grid()

# %% [markdown]
# # SVM

# %%
X = data[['AR','AMT','AMiT','AH','AWS','ACC','ABS','Potato Area']].values
y = data['Potato Production'].values

# %% [markdown]
# X_train = X[:83]
# y_train = y[:83]
#
# X_test = X[83:]
# y_test = y[83:]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.5)

# %%
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2)

# %% [markdown]
# lab_enc = preprocessing.LabelEncoder()
# y_train = lab_enc.fit_transform(y_train)
# print(y_train)
# print(utils.multiclass.type_of_target(y_train))
# #print(utils.multiclass.type_of_target(y_train.astype('int')))
# print(utils.multiclass.type_of_target(y_train))

# %%
#Import svm model
from sklearn import svm

#Create a svm Classifier
reg = svm.SVR(kernel='linear') # Linear Kernel

#Train the model using the training sets
reg.fit(X_train, y_train)

#Predict the response for test dataset
y_pred1 = reg.predict(X_test)

from sklearn import metrics
from sklearn.metrics import accuracy_score,confusion_matrix
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred1)/100000)  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred1)/(100000*100000))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred1))/100000)


#Visualizing the results
plt.figure(figsize=(10,5))
#plt.title('Foreign Exchange Rate of %s by Lasso Regression')
plt.plot(y_test , label = 'Actual', color = 'b')
plt.plot(y_pred1 , label = 'Predicted', color = 'c')
plt.legend()
#plt.savefig("%s + Lasso.png"%var)

from sklearn.metrics import r2_score

#print('Variance score: %.2f' % model.score(X_test, y_test))
print("R2 score : %.2f" % r2_score(y_test,y_pred1))
# Out:
# Mean Absolute Error: 0.6875677824768592
# Mean Squared Error: 1.4750984932004112
# Root Mean Squared Error: 1.214536328481125
# R2 score : 0.88

# %%
y_test.shape
# Out:
# (52,)

# %%
df = pd.DataFrame({'Actual': y_test, 'Pred_SVM': y_pred1})
#df1 = df.head(20)

# %%
df.plot(kind='bar',figsize=(16,8))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()

# %% [markdown]
# # Naive Bias

# %% [markdown]
# X = data[['AR','AMT','AMiT','AH','AWS','ACC','ABS','Wheat Area']].values
# y = data['Wheat Production'].values

# %%
#Import Gaussian Naive Bayes model
from sklearn.naive_bayes import GaussianNB

#Create a Gaussian Classifier
model = GaussianNB()

# Train the model using the training sets
model.fit(X_train,y_train)

#Predict Output
y_pred2= model.predict(X_test) # 0:Overcast, 2:Mild
#print("Predicted Value:", y_pred)

print("R2 score : %.2f" % r2_score(y_test,y_pred2))
# Out:
# R2 score : 0.97

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred2)/100000)  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred2)/(100000*100000))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred2))/100000)
# Out:
# Mean Absolute Error: 0.40689942307692306
# Mean Squared Error: 0.4158213747019231
# Root Mean Squared Error: 0.6448421316120118

# %%
df = pd.DataFrame({'Actual': y_test.flatten(), 'Pred_NB': y_pred2.flatten()})
df
# Out:
#      Actual  Pred_NB
# 0    353860   563103
# 1    841979   757983
# 2    239960   263460
# 3     41905    39610
# 4   1018177  1119779
# 5    563103   563103
# 6     93090   143400
# 7     67130    64120
# 8   1041781  1041781
# 9     62015    90960
# 10    93025    96357
# 11   675280   563103
# 12    86145    85255
# 13   117740    86730
# 14   409620   563103
# 15   347994   297639
# 16    93925   143400
# 17    50590    73010
# 18    80555    79330
# 19   623499   563103
# 20    63140    58127
# 21    75804    58127
# 22   621462   563103
# 23    92795   143400
# 24   426195   412775
# 25    58495    64120
# 26    60164    64120
# 27    74650    75810
# 28   224040   235625
# 29    41330    48020
# 30   243895   276934
# 31   538005   538005
# 32    94225   143400
# 33    16210    41010
# 34   757983   757983
# 35  1143156  1041781
# 36   623499   563103
# 37    60520    85255
# 38  1018177  1119779
# 39   375348   412775
# 40   841979   757983
# 41    92795   143400
# ...

# %%
df.plot(kind='bar',figsize=(10,8))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.title("Rice production for Dinajpur")
plt.show()

# %%
plt.plot(df)

# %%
from sklearn.linear_model import BayesianRidge, LinearRegression
#from sklearn.naive_bayes import GaussianNB

#Create a Gaussian Classifier
model = BayesianRidge(compute_score=True)

# Train the model using the training sets
model.fit(X_train,y_train)

#Predict Output
y_pred= model.predict(X_test) # 0:Overcast, 2:Mild
print("Predicted Value:", y_pred)
# Out:
# Predicted Value: [487717.20445592 619626.59721889 285930.7329695   52167.91184112
#  774912.37745876 494177.14364818 154567.32385303  98653.2160879
#  718960.21803775  85346.1782458  132827.32571384 509063.62517181
#   77939.09972184 117141.83089032 511140.08386193 331756.83799597
#  155856.53781942  80650.45466806 102147.84957127 510876.23631607
#   95253.02680828  94829.53141214 511578.32241331 155347.0055502
#  399795.11438743  97932.67410005  98896.14277919 109640.14961714
#  258437.03494297  57256.23079022 282404.18791553 410268.17361185
#  156101.67689817   1224.77132433 601290.35008623 736376.35296582
#  510876.50861418  72551.29607149 774912.37745876 395547.57211569
#  619627.91625712 155352.49467619 119610.7193806  107505.08457746
#  736376.35296582 310700.95977955  78664.91744802 549233.91904069
#  763557.51158927 113799.79890957 486266.49907412 574066.63196796]

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 98241.35684571894
# Mean Squared Error: 23322020605.55874
# Root Mean Squared Error: 152715.489082014

# %% [markdown]
# # Random Forest

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.ensemble import RandomForestRegressor

regressor = RandomForestRegressor(n_estimators=20, random_state=0)
regressor.fit(X_train, y_train)
y_pred3 = regressor.predict(X_test)

# %%
from sklearn import metrics

print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred3)/100000)
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred3)/10000000000)
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred3))/100000)
print("R2 score : %.2f" % r2_score(y_test,y_pred3))
# Out:
# Mean Absolute Error: 0.9193285673076923
# Mean Squared Error: 1.8264930759324955
# Root Mean Squared Error: 1.3514781078258338
# R2 score : 0.85

# %%
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred3})

# %%
df
# Out:
#      Actual   Predicted
# 0    353860   393137.90
# 1    841979  1025330.90
# 2    239960   337781.30
# 3     41905    48356.25
# 4   1018177   839148.90
# 5    563103   542305.30
# 6     93090   131704.60
# 7     67130   223210.25
# 8   1041781  1049328.00
# 9     62015    76379.50
# 10    93025    94151.30
# 11   675280   359688.50
# 12    86145    99010.25
# 13   117740   107025.75
# 14   409620   298830.75
# 15   347994   268012.80
# 16    93925   114014.80
# 17    50590    85558.55
# 18    80555    84924.65
# 19   623499   380577.10
# 20    63140    77263.90
# 21    75804    79022.30
# 22   621462   340653.60
# 23    92795    95416.45
# 24   426195   263990.50
# 25    58495    82507.50
# 26    60164    82507.50
# 27    74650    91681.30
# 28   224040   388080.60
# 29    41330    51299.75
# 30   243895   202978.90
# 31   538005   434453.90
# 32    94225   122085.75
# 33    16210    48641.50
# 34   757983   897292.80
# 35  1143156   923956.80
# 36   623499   512874.05
# ...

# %%
df.plot(kind='bar',figsize=(10,8))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()

# %%
plt.plot(df)

# %% [markdown]
# ## Ridge

# %%
from sklearn import metrics
from sklearn.linear_model import Ridge
from sklearn.metrics import accuracy_score,confusion_matrix
model = Ridge(alpha=.01)
model.fit(X_train, y_train) 
y_pred4= model.predict(X_test)

#Mean Squared Error
from sklearn import metrics
from sklearn.metrics import accuracy_score,confusion_matrix
#mean_squared_error(y_test, y_pred)
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred4)/100000)  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred4)/10000000000)  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred4))/100000)
print("R2 score : %.2f" % r2_score(y_test,y_pred4))
# Out:
# Mean Absolute Error: 1.139758416673212
# Mean Squared Error: 3.2536357915086547
# Root Mean Squared Error: 1.803783742999325
# R2 score : 0.73

# %%
df.plot(kind='bar',figsize=(10,8))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()
#plt.savefig("%s + Ridge.pn")

# %% [markdown]
# ## KRR

# %%
# evaluate base models in isolation on the regression dataset
from numpy import hstack
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.linear_model import Ridge
from sklearn.ensemble import RandomForestRegressor
 
# get the dataset
#def get_dataset():
#	X, y = make_regression(n_samples=10000, n_features=20, n_informative=10, noise=0.3, random_state=7)
#	return X, y
 
# get a list of base models
def get_models():
	models = list()
#	models.append(('lr', LinearRegression()))
	models.append(('knn', KNeighborsRegressor()))
#	models.append(('cart', DecisionTreeRegressor()))
#	models.append(('svm', SVR()))
	models.append(('rd', Ridge(alpha = 0.1)))
	models.append(('rf', RandomForestRegressor()))
#	models.append(('ls', Lasso(alpha=0.01)))
	return models
 
# define dataset
#X, y = get_dataset()
# split dataset into train and test sets
#X_train_full, X_test, y_train_full, y_test = train_test_split(X, y, test_size=0.5, random_state=1)
# summarize data split
#print('Train: %s, Test: %s' % (X_train_full.shape, X_test.shape))
# create the base models
models = get_models()
# evaluate standalone model
for name, model in models:
	# fit the model on the training dataset
	model.fit(X_train,y_train)
	# make a prediction on the test dataset
	y_pred5 = model.predict(X_test)
	# evaluate the predictions
#	score = mean_absolute_error(y_test, yhat)
	# report the score
#	print('>%s MAE: %.3f' % (name, score))

# %%
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred4)/100000)  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred5)/(100000*100000))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred5))/100000)

print("R2 score : %.2f" % r2_score(y_test,y_pred5))
# Out:
# Mean Absolute Error: 1.139758416673212
# Mean Squared Error: 1.8417682812617904
# Root Mean Squared Error: 1.3571176372230194
# R2 score : 0.85

# %% [markdown]
# #Visualizing the results
# print(len(y_test))
# xx = data["Year"]
#
# xx= xx[82:]
# plt.figure(figsize=(12,6))
# plt.title("Crude Oil Price Prediction Using LKDSR")
# plt.xlabel('Data Sample According to Time')
# plt.ylabel('Crude Oil Price')
#
# plt.plot(xx,y_test , label = 'Actual', color = 'r')
# plt.plot(y_pred5 , label = 'Predicted', color = 'b')
# plt.xticks(rotation=90)
# plt.legend()
# #plt.grid(color='k', linestyle='-', linewidth=1)
# #plt.savefig("lkdsr.png")

# %%
#df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred1})

# %% [markdown]
# import matplotlib.pyplot as plt
# import seaborn as sns
#
# xx = data["Year"]
#
# xx= xx[78:]
#
# print(len(xx))
#
# sns.set_theme(style="darkgrid")
#
# plt.figure(figsize=(12,6))
# #sns.lineplot(data = df)
# sns.lineplot(xx,y_pred1,label = 'Actual', color = 'r')
# sns.lineplot(xx,y_test, label = 'Predicted', color = 'b')
# plt.xticks(rotation=90)
# plt.legend()
# plt.show()

# %%
df.plot(kind='bar',figsize=(12,6))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()

# %% [markdown]
# ## Catboost

# %%
from catboost import CatBoostRegressor
model_cat=CatBoostRegressor()
#categorical_features_indices = np.where(df.dtypes != np.float)[0]
model_cat.fit(X_train,y_train)
model_cat.score(X_test,y_test)

y_pred6 = model_cat.predict(X_test)

from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred6)/100000)  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred6)/(100000*100000))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred6))/100000)

print("R2 score : %.2f" % r2_score(y_test,y_pred6))
# Out:
# Learning rate set to 0.025584
# 0:	learn: 328971.9660208	total: 163ms	remaining: 2m 42s
# 1:	learn: 324641.3898089	total: 166ms	remaining: 1m 22s
# 2:	learn: 322126.3508857	total: 168ms	remaining: 55.7s
# 3:	learn: 318515.5669352	total: 170ms	remaining: 42.3s
# 4:	learn: 313263.4084455	total: 171ms	remaining: 34.1s
# 5:	learn: 308631.9683970	total: 173ms	remaining: 28.6s
# 6:	learn: 303363.5551474	total: 177ms	remaining: 25.1s
# 7:	learn: 299090.4565973	total: 179ms	remaining: 22.2s
# 8:	learn: 295736.5546116	total: 181ms	remaining: 20s
# 9:	learn: 291791.2499485	total: 184ms	remaining: 18.2s
# 10:	learn: 287990.8079757	total: 186ms	remaining: 16.7s
# 11:	learn: 283116.4943093	total: 189ms	remaining: 15.5s
# 12:	learn: 279572.5769601	total: 191ms	remaining: 14.5s
# 13:	learn: 276138.0416395	total: 192ms	remaining: 13.5s
# 14:	learn: 272629.5323571	total: 193ms	remaining: 12.7s
# 15:	learn: 268715.6820878	total: 194ms	remaining: 11.9s
# ...

# %%
plt.figure(figsize=(12,6))
plt.title("Wheat Production Prediction Using CatBoost")
plt.xlabel('Data Sample According to Time')
plt.ylabel('Wheat Production')
plt.plot(y_test , label = 'Actual', color = 'r')
plt.plot(y_pred6 , label = 'Predicted', color = 'b')
plt.legend()
plt.grid(color='k', linestyle='-', linewidth=1)

# %%
df = pd.DataFrame({'Actual': y_test.flatten(), 'Pred_NB': y_pred2.flatten(),'Pred_RF': y_pred3.flatten(),'Pred_Ridge': y_pred4.flatten(),'Pred_Cat': y_pred6.flatten(),'Pred_KRR': y_pred5.flatten()})
df
# Out:
#      Actual  Pred_NB     Pred_RF     Pred_Ridge      Pred_Cat    Pred_KRR
# 0    353860   563103   393137.90  420469.589283  3.371511e+05   410818.65
# 1    841979   757983  1025330.90  832469.467669  9.691347e+05   926025.44
# 2    239960   263460   337781.30  308936.389358  2.689544e+05   338766.33
# 3     41905    39610    48356.25   48994.126928  4.062214e+04    45635.80
# 4   1018177  1119779   839148.90  817325.023284  6.473735e+05   857461.15
# 5    563103   563103   542305.30  812752.175780  4.578997e+05   572974.62
# 6     93090   143400   131704.60  -49099.076490  1.303387e+05   118399.67
# 7     67130    64120   223210.25  451864.582074  2.190229e+05   323336.15
# 8   1041781  1041781  1049328.00  887374.023502  1.041175e+06  1008230.73
# 9     62015    90960    76379.50  141206.118736  7.887495e+04    74078.36
# 10    93025    96357    94151.30  101796.179726  1.001581e+05    98633.12
# 11   675280   563103   359688.50  473588.241808  4.724351e+05   360611.38
# ...

# %%
df.to_csv("Boro Result.csv")

# %%
plt.figure(figsize=(12,6))
plt.plot(df[10:])
plt.legend()
plt.grid()
# Out:
# No handles with labels found to put in legend.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(12,6))
sns.set_theme(style="whitegrid")
xx = data["Year"]  # year list

xx= xx[82:]   # it is sub section of an array
sns.lineplot(xx)
sns.lineplot(data = df[10:])
plt.title("Wheat Production Prediction using Different Models")
plt.xticks(rotation=65)
plt.xlabel("Year")
plt.ylabel("Wheat Production")
#plt.grid()
#plt.savefig("Wheat_line.png")
plt.show()
# Out:
# C:\Users\mahmu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df[15:].plot(kind='bar',figsize=(12,6))
plt.title("Wheat Production Prediction using Different Models")
plt.xlabel("Bar for different Models")
plt.ylabel("Wheat Production")
plt.xticks(rotation=65)
#plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
#plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
#plt.savefig("Wheat_bar.png")
plt.show()

# %% [markdown]
# ### Boro

# %%
df1 = pd.read_csv("Boro.csv")

df1

#print(type(df1))
# Out:
#           Method      MAE      MSE     RMSE
# 0            SVR  0.53504  0.55281  0.74351
# 1     Na�ve Bias  0.48926  0.47806  0.42198
# 2  Random Forest  0.28492  0.22161  0.47076
# 3          Ridge  0.44704  0.31240  0.55892
# 4       CatBoost  0.45308  0.25944  0.39929
# 5            KRR  0.44700  0.26608  0.41583

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(12,6))
sns.set_theme(style="whitegrid")
xx = ['SVR', 'Naive Bias', 'Random Forest', 'Ridge','CatBoost','KRR']

plt.plot(xx,df1["MSE"],label="MSE",linewidth = 3, linestyle = '-.', marker = 'D')
plt.plot(xx,df1["MAE"],label="MAE",linewidth = 3, linestyle = '-.', marker = 's')
plt.plot(xx,df1["RMSE"],label="RMSE",linewidth = 3, linestyle = '-.', marker = 'o')
#plt.set_xticklabels(x_str)
plt.title("Errors of Different Methods for Boro Rice Prediction")
plt.xticks(rotation=15)
plt.xlabel("Methods")
plt.ylabel("Errors")
plt.legend()
#plt.savefig("Boro_Error.png")
plt.show()
